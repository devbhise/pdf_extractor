# %% [markdown]
# <a href="https://colab.research.google.com/github/devbhise/pdf_extractor/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install PyMuPDF transformers sentence-transformers spacy

import fitz  # PyMuPDF for PDF parsing
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
import spacy

# Initialize models
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
nlp = spacy.load("en_core_web_sm")
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# Define keywords for different sections (customize based on investor focus)
keywords = {
    "growth_prospects": ["growth", "outlook", "prospects"],
    "business_changes": ["acquisition", "strategy", "restructuring", "business changes"],
    "key_triggers": ["risk", "opportunity", "trigger", "impact"],
    "material_effects": ["financial performance", "earnings", "profit", "revenue"]
}

# Function to parse PDF and split into chunks
def parse_pdf_to_chunks(file_path, chunk_size=1000):
    text_chunks = []
    with fitz.open(file_path) as pdf:
        text = ""
        for page_num in range(pdf.page_count):
            text += pdf[page_num].get_text("text")
            if len(text) >= chunk_size:
                text_chunks.append(text)
                text = ""
        if text:  # Add any remaining text
            text_chunks.append(text)
    return text_chunks

# Function to identify key themes in each chunk based on similarity
def detect_theme(chunk, keywords):
    theme = {}
    chunk_embeddings = embedder.encode(chunk, convert_to_tensor=True)

    for section, kw_list in keywords.items():
        matched_text = ""
        for keyword in kw_list:
            keyword_embedding = embedder.encode(keyword, convert_to_tensor=True)
            cosine_scores = util.cos_sim(keyword_embedding, chunk_embeddings).flatten()
            threshold = 0.3  # Adjust based on keyword relevance
            matched_text += " ".join([chunk.splitlines()[i] for i in range(len(cosine_scores)) if cosine_scores[i] > threshold])
        theme[section] = matched_text
    return theme

# Summarization function for each chunk
def summarize_chunk(chunk, min_length=50, max_length=150):
    try:
        summary = summarizer(chunk, min_length=min_length, max_length=max_length, do_sample=False)
        return summary[0]['summary_text']
    except Exception as e:
        return "Summary not available"

# Extract entities and relevant insights
def extract_entities_and_sentiment(chunk):
    doc = nlp(chunk)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# Main function to process large document in chunks
def analyze_pdf_in_chunks(file_path):
    chunks = parse_pdf_to_chunks(file_path)
    report = {}

    for i, chunk in enumerate(chunks):
        theme_content = detect_theme(chunk, keywords)
        chunk_summary = summarize_chunk(chunk)
        entities = extract_entities_and_sentiment(chunk)

        # Organize output by chunk and theme
        report[f"Chunk_{i+1}"] = {
            "summary": chunk_summary,
            "themes": theme_content,
            "entities": entities
        }

    return report

# Path to PDF
file_path = '/content/SJS Transcript Call.pdf'  # Update with your file path

# Run analysis
report = analyze_pdf_in_chunks(file_path)

# Display report
for chunk, data in report.items():
    print(f"\n--- {chunk} ---")
    print("Summary:", data["summary"])
    for theme, content in data["themes"].items():
        print(f"{theme.capitalize()}:", content[:300] + "...")  # Preview each theme
    print("Entities:", data["entities"])
# Out:
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.13-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading PyMuPDF-1.24.13-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 64.1 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.24.13
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# --- Chunk_1 ---
# Summary:  transcripts of Analysts/Investor Meet/ Earnings Call of Q1 FY 2023-24 held on July 27, 2023. You are requested to kindly take the same on record. For S.J.S. Enterprises Limited, Thabraz Hushain W. is the Company Secretary and Compliance Officer.
# Growth_prospects:  ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:  ...
# Entities: [('August 03', 'DATE'), ('2023', 'DATE'), ('National Stock Exchange of India Limited \nExchange', 'ORG'), ('5th Floor', 'FAC'), ('G Block', 'ORG'), ('Bandra', 'PERSON'), ('Kurla Complex', 'PERSON'), ('Bandra', 'PERSON'), ('Mumbai', 'GPE'), ('051', 'CARDINAL'), ('SJS', 'ORG'), ('BSE Limited \nCorporate Relationship Department', 'ORG'), ('2nd Floor', 'ORG'), ('Rotunda Building', 'PERSON'), ('P.J. Towers', 'ORG'), ('Dalal Street', 'FAC'), ('Mumbai', 'GPE'), ('400', 'CARDINAL'), ('ISIN', 'ORG'), ('Dear Sir/Madam', 'WORK_OF_ART'), ('Q1', 'CARDINAL'), ('2023-24', 'DATE'), ('the Analysts/Investor Meet/ Earnings Call of Q1 FY', 'EVENT'), ('2023-24', 'DATE'), ('July 27, 2023', 'DATE'), ('For S.J.S. Enterprises Limited', 'ORG'), ('Thabraz Hushain W.  \nCompany', 'PERSON'), ('WAJID AHMED\nDigitally', 'PERSON'), ('WAJID AHMED \nDate', 'PERSON'), ('2023.08.03', 'CARDINAL')]
#
# --- Chunk_2 ---
# Summary: SJS Enterprises Limited Q1 FY2024 Earnings Conference Call    July 27, 2023, at 10:30 a.m. ET. Hosted by JM Financial. All participant lines will be in the listen-only mode. There will be an opportunity for you to ask questions after the presentation.
# Growth_prospects: ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:  ...
# Entities: [('SJS Enterprises Limited', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('RONAK MEHTA', 'PERSON'), ('JM FINANCIAL \n \nMANAGEMENT:', 'ORG'), ('K.A. JOSEPH', 'PERSON'), ('MAHENDRA NAREDI', 'PERSON'), ('MS', 'ORG'), ('DEVANSHI DHRUVA', 'PERSON'), ('SJS Enterprises', 'ORG'), ('July 27, 2023 \n \n', 'DATE'), ('the SJS Enterprises', 'ORG'), ('JM Financial', 'ORG'), ('Ronak Mehta', 'PERSON'), ('JM Financial', 'ORG'), ('Mehta', 'PERSON'), ('Ronak Mehta', 'PERSON'), ('JM Financial Institutional Securities', 'ORG'), ('the Management Team', 'ORG'), ('today', 'DATE'), ('K A', 'PERSON'), ('Joseph', 'PERSON'), ('Co-Founder', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('Mahendra', 'PERSON'), ('Devanshi Dhruva', 'PERSON'), ('Devanshi', 'PERSON'), ('Devanshi Dhruva', 'PERSON'), ('Ronak', 'PERSON'), ('today', 'DATE'), ('today', 'DATE'), ('Joseph', 'PERSON'), ('M.D. and Co-Founder', 'ORG'), ("Walter Pack India's", 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('Sanjay', 'PERSON'), ('Mahendra Naredi', 'PERSON'), ('CFO', 'ORG'), ('around 60 minutes', 'TIME'), ('about 20 minutes', 'TIME'), ('Joseph', 'PERSON'), ('Joe', 'PERSON'), ('K.A. Joseph', 'PERSON'), ('Devanshi', 'PERSON'), ('Investor Presentation', 'EVENT'), ('yesterday', 'DATE')]
#
# --- Chunk_3 ---
# Summary: SJS Enterprises has completed the transformative acquisition of Walter Pack India. The acquisition has opened up a plethora of new opportunities for SJS. Walter Pack Q1 witnessed a strong revenue growth of 21% YoY and a robust margin performance with EBITDA margins around 31.5%. SJS believes inorganic acquisitions will continue to be our core strategy.
# Growth_prospects:  ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Sanjay', 'GPE'), ('Mahendra', 'PERSON'), ('Walter Pack India', 'PERSON'), ('Exotech', 'ORG'), ('last two years', 'DATE'), ('SJS', 'ORG'), ('Walter Pack  ', 'PERSON'), ('two', 'CARDINAL'), ('SJS', 'ORG'), ('Walter Pack India', 'PERSON'), ('36%', 'PERCENT'), ('two', 'CARDINAL'), ('36%', 'PERCENT'), ('28%', 'PERCENT'), ('Exotech', 'PERSON'), ('Walter Pack', 'PERSON'), ('two', 'CARDINAL'), ('Walter Pack', 'PERSON'), ('Roy Mathew', 'PERSON'), ('one', 'CARDINAL'), ('Walter Pack India', 'PERSON'), ('Walter Pack', 'PERSON'), ('10%', 'PERCENT'), ('SJS', 'ORG'), ('three', 'CARDINAL'), ('Walter Pack India', 'PERSON'), ('this quarter', 'DATE'), ('Walter Pack Q1', 'PERSON'), ('21%', 'PERCENT'), ('YoY', 'GPE'), ('31.5%', 'PERCENT'), ('nine months', 'DATE'), ('Walter Pack India', 'PERSON'), ('SJS', 'ORG'), ('Sanjay', 'GPE'), ('the quarter', 'DATE'), ('Sanjay', 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('Joe', 'PERSON'), ('Walter Pack', 'PERSON')]
#
# --- Chunk_4 ---
# Summary: SJS has been consistently growing ahead of the industry and this quarter is no different. Overall consolidated SJS sales grew by 13.6% year-on-year, partially impacted on account of slow recovery in the consumer appliances segment and some degrowth in the farm equipment segment.
# Growth_prospects: ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:   ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27, 2023', 'DATE'), ('the 15th consecutive quarter', 'DATE'), ('SJS', 'ORG'), ('Exotech', 'ORG'), ('13.6%', 'PERCENT'), ('YoY', 'GPE'), ('18.6%', 'PERCENT'), ('YoY', 'GPE'), ('two', 'CARDINAL'), ('14.2%', 'PERCENT'), ('YoY', 'GPE'), ('about 120.7%', 'PERCENT'), ('million', 'CARDINAL'), ('Rs.2,849.7 million', 'CARDINAL'), ('30th June', 'DATE'), ('Walter Pack', 'PERSON'), ('461.7 million', 'CARDINAL'), ('539.8 million', 'CARDINAL'), ('two', 'CARDINAL'), ('Toyota', 'ORG'), ('Tsusho', 'PERSON'), ('Autoliv', 'GPE'), ('Autoliv', 'GPE'), ('IML', 'ORG'), ('SJS', 'ORG'), ('this quarter', 'DATE'), ('Q1', 'CARDINAL'), ('two', 'CARDINAL'), ('1.3%', 'PERCENT'), ('YoY', 'GPE'), ('SJS', 'ORG'), ('two', 'CARDINAL'), ('15%', 'PERCENT'), ('24.6%', 'PERCENT'), ('YoY', 'GPE'), ('7%', 'PERCENT'), ('two', 'CARDINAL'), ('only 2.3%', 'PERCENT'), ('YoY', 'GPE'), ('SJS', 'ORG'), ('18.6%', 'PERCENT'), ('YoY', 'GPE'), ('SJS', 'ORG'), ('13.6%', 'PERCENT'), ('year-on-year', 'DATE'), ('the quarter', 'DATE'), ('last year same quarter', 'DATE'), ('Europe', 'LOC'), ('North \nAmerica', 'GPE'), ('this quarter', 'DATE'), ('South America', 'LOC'), ('EMEA', 'ORG'), ('South America', 'LOC'), ('North America', 'LOC'), ('Europe', 'LOC'), ('North America', 'LOC'), ('Europe', 'LOC'), ('one', 'CARDINAL'), ('two', 'CARDINAL'), ('Autoliv', 'ORG'), ('Toyota', 'ORG'), ('Tsusho', 'PRODUCT'), ('Mahindra', 'ORG'), ('TVS', 'ORG'), ('Visteon', 'ORG'), ('Hyundai', 'ORG'), ('Bajaj Auto Continental', 'ORG'), ('Honda Motorcycles & Scooters', 'ORG')]
#
# --- Chunk_5 ---
# Summary: SJS Enterprises' consolidated revenue at Rs.1,172.5 million has grown at 13.6% YoY on the back of strong growth in automotive segment and exports. Domestic sales outperformed the underlying automotive industry growth. Exports during this quarter grew by 90.8% on YoY basis on account of new business wins and export market recovery.
# Growth_prospects: ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:  ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27, 2023 \n \n', 'DATE'), ('Mahendra', 'PERSON'), ('one', 'CARDINAL'), ('CSR', 'ORG'), ('Manikandan', 'PERSON'), ('the past seven years', 'DATE'), ('year-after-year', 'DATE'), ('India', 'GPE'), ('World Cup', 'EVENT'), ("June '23", 'DATE'), ('Switzerland', 'GPE'), ('Swachh', 'NORP'), ('5', 'CARDINAL'), ('12', 'CARDINAL'), ('CSR', 'ORG'), ('Mahendra', 'PERSON'), ('CFO', 'ORG'), ('SJS', 'ORG'), ('Mahendra', 'PERSON'), ('Mahendra Naredi', 'PERSON'), ('Thapar', 'PERSON'), ('Good morning', 'TIME'), ('12', 'CARDINAL'), ('Rs.1,172.5 million', 'CARDINAL'), ('13.6%', 'PERCENT'), ('YoY', 'GPE'), ('SJS', 'ORG'), ('14.2%', 'PERCENT'), ('YoY', 'GPE'), ('around 10%', 'PERCENT'), ('8.4%', 'PERCENT'), ('YoY', 'GPE'), ('this quarter', 'DATE'), ('90.8%', 'PERCENT'), ('YoY', 'GPE'), ('PV', 'FAC'), ('11%', 'PERCENT'), ('6%', 'PERCENT'), ('last year', 'DATE'), ('Rs.313.8 million', 'CARDINAL'), ('12.8%', 'PERCENT'), ('YoY', 'GPE'), ('26.1%', 'PERCENT'), ('30', 'CARDINAL'), ('YoY', 'GPE'), ('one', 'CARDINAL'), ('Rs.8 million', 'CARDINAL'), ('GST', 'ORG'), ('PAT', 'ORG'), ('Rs.180 million', 'CARDINAL'), ('11.1%', 'PERCENT'), ('YoY', 'GPE'), ('PAT', 'ORG'), ('15.4%', 'PERCENT'), ('the quarter', 'DATE'), ('38.6%', 'PERCENT'), ('ROE', 'ORG'), ('14.5%', 'PERCENT'), ('Thapar', 'PERSON'), ('Rs.2,849.7 million', 'CARDINAL'), ('Walter Pack India', 'PERSON'), ('Rs.461.7 million', 'CARDINAL'), ('million', 'CARDINAL'), ('Joseph', 'PERSON'), ('15.5%', 'PERCENT'), ('16.9%', 'PERCENT'), ('13', 'CARDINAL'), ('quarterly', 'DATE'), ('SJS', 'ORG'), ('Walter Pack India', 'PERSON'), ('Q1', 'CARDINAL'), ('Walter Pack India', 'PERSON')]
#
# --- Chunk_6 ---
# Summary: From Q2 onwards, WPI financial will be consolidated with the SJS                 numbers, basis our 90.1% holding in Walter Pack India. Pro forma revenue for Q1 FY24 would have been Rs.1,528.7 million, a YoY growth of                 48.2%. Proforma EBITDA margin were at 27.3%, witnessing 120 bps margin expansion as                 compared to Q1FY24 reported margin.
# Growth_prospects:  ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects:     ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('this quarter', 'DATE'), ('Q2', 'CARDINAL'), ('SJS', 'ORG'), ('90.1%', 'PERCENT'), ('Walter Pack India', 'PERSON'), ('Joseph', 'PERSON'), ('Walter Pack', 'PERSON'), ('the year', 'DATE'), ('YoY', 'GPE'), ('48.2%', 'PERCENT'), ('27.3%', 'PERCENT'), ('120', 'CARDINAL'), ('52.1%', 'PERCENT'), ('EPS', 'ORG'), ('51.8%', 'PERCENT'), ('Walter Pack', 'PERSON'), ('EPS', 'ORG'), ('21%', 'PERCENT'), ('EPS', 'ORG'), ('Walter Pack \n', 'PERSON'), ('India', 'GPE'), ('EPS', 'ORG'), ('Walter Pack', 'PERSON'), ('three', 'CARDINAL'), ('Thapar', 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('Mahendra', 'PERSON'), ('Exotech', 'ORG'), ('two', 'CARDINAL'), ('Exotech', 'PERSON'), ('Walter Pack', 'PERSON'), ('Ranjangaon', 'GPE'), ('Pune', 'GPE'), ('a year', 'DATE'), ("year '24", 'DATE'), ('Walter Pack', 'PERSON'), ('Exotech', 'PERSON'), ('Exotech', 'PERSON'), ('Exotech', 'ORG'), ('Exotech', 'ORG'), ('26', 'CARDINAL'), ('20% to 25%', 'PERCENT')]
#
# --- Chunk_7 ---
# Summary: SJS has already started accelerating its efforts to increase its value in both two-wheeler, passenger vehicle and consumer segments. SJS is also working on a few new age products like optical plastics and cover glass, which will further drive ophobicup the kit value that we supply to customers.
# Growth_prospects:   ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('SJS', 'ORG'), ('two', 'CARDINAL'), ('Exotech', 'ORG'), ('IML', 'ORG'), ('IMD', 'ORG'), ('IMF', 'ORG'), ('Walter Pack', 'PERSON'), ('SJS', 'ORG'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('20% - 25%', 'PERCENT'), ('SJS', 'ORG'), ('50%', 'PERCENT'), ('YoY', 'GPE'), ('SJS', 'ORG'), ('about 40%', 'PERCENT'), ('YoY', 'GPE'), ('Walter Pack', 'PERSON'), ('90.1%', 'PERCENT'), ('Walter Pack', 'PERSON'), ('a nine month', 'DATE'), ('this financial year', 'DATE'), ('quarterly', 'DATE'), ('first', 'ORDINAL'), ('Amit Hiranandani', 'ORG'), ('SMIFS Limited', 'ORG'), ('first', 'ORDINAL'), ('Mahendra Naredi', 'PERSON'), ('this quarter', 'DATE'), ('around 10%', 'PERCENT'), ('the last year', 'DATE'), ('Amit Hiranandani', 'ORG'), ('Exotech', 'ORG'), ('QoQ', 'ORG'), ('annual', 'DATE'), ('three years', 'DATE'), ('Mahendra Naredi', 'PERSON'), ('this quarter', 'DATE'), ('Exotech', 'ORG'), ('14% to 15%', 'PERCENT')]
#
# --- Chunk_8 ---
# Summary: Sanjay Thapar: SJS inherited a legacy of existing customers. The margins that are there are largely what are agreed with Exotech in the past. We are still maintaining our guidance about 14% - 15% EBITDA margins for next 2-3 years.
# Growth_prospects:  ...
# Business_changes:   ...
# Key_triggers: ...
# Material_effects:  ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('the next three years', 'DATE'), ('Sanjay Thapar', 'PERSON'), ('Exotech', 'PERSON'), ('about 14% - 15%', 'PERCENT'), ('2-3 years', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('the last two years', 'DATE'), ('around 11% - 12%', 'PERCENT'), ('the last two years', 'DATE'), ('300', 'CARDINAL'), ('last year', 'DATE'), ('around 15%', 'PERCENT'), ('14% to 15%', 'PERCENT'), ('Exotech', 'ORG'), ('one year', 'DATE'), ('Sanjay Thapar', 'PERSON'), ('Exotech', 'ORG'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('Walter Pack', 'PERSON'), ('Exotech', 'PERSON'), ('one year', 'DATE'), ('Exotech', 'ORG'), ('Exotech', 'ORG'), ('Devanshi Dhruva', 'PERSON'), ('Exotech', 'PERSON'), ('WPI', 'PERSON'), ('Exotech', 'ORG'), ('Devanshi Dhruva', 'PERSON'), ('this year', 'DATE'), ('SJS', 'ORG'), ('10-12', 'CARDINAL'), ('Exotech', 'PERSON'), ('10-12', 'CARDINAL'), ('Walter Pack', 'PERSON'), ('the next nine months', 'DATE'), ('10', 'CARDINAL'), ('this year', 'DATE')]
#
# --- Chunk_9 ---
# Summary: Mahendra Naredi: We believe that it will not impact our margins. The raw material cost Is going up. But at the same time, the manufacturing, the admin and                 employee cost will not increase to that extent.Devanshi Dhruva: We will try and maintain our 25% to 27%margins.
# Growth_prospects: ...
# Business_changes:   ...
# Key_triggers: ...
# Material_effects:  ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27, 2023 \n \n', 'DATE'), ('Joseph George', 'PERSON'), ('Joseph George:', 'PERSON'), ('one', 'CARDINAL'), ('Exotech', 'ORG'), ('third', 'ORDINAL'), ('Exotech', 'ORG'), ('the coming year or so', 'DATE'), ('Mahendra Naredi', 'PERSON'), ('Joseph', 'PERSON'), ('PAT', 'ORG'), ('PAT', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('ROC', 'GPE'), ('Devanshi Dhruva', 'PERSON'), ('25% to 27%', 'PERCENT'), ('Amit Hiranandani', 'ORG'), ('second', 'ORDINAL'), ('CAPEX', 'ORG'), ('last year', 'DATE'), ('Exotech', 'GPE'), ('300', 'CARDINAL'), ('a year or', 'DATE'), ('CAPEX', 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('Exotech', 'PERSON'), ('Exotech', 'ORG'), ('Piyush Parag', 'PERSON'), ('Nuvama Wealth', 'LOC'), ('Piyush Parag', 'PERSON'), ('WPI', 'PERSON'), ('WPI', 'ORG'), ('the quarter', 'DATE'), ('years', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('Piyush Parag', 'PERSON'), ('WPI', 'ORG'), ('the quarter', 'DATE'), ('the next 2-3 years', 'DATE')]
#
# --- Chunk_10 ---
# Summary: Walter Pack India has done this quarter 356 million sales turnover with an EBITDA of 31.5%. Walter Pack Spain, which was the parent of Walter Pack India, is amongst the global benchmarks for in-mold forming and IML technologies. Walter Pack is going to actually help us introduce a lot of new  neurologicaltechnologies to the customers in India and overseas.
# Growth_prospects:   ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:   ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Mahendra Naredi', 'PERSON'), ('Walter Pack India', 'PERSON'), ('356 million', 'CARDINAL'), ('31.5%', 'PERCENT'), ('20% to 25%', 'PERCENT'), ('Walter Pack', 'PERSON'), ('75%', 'PERCENT'), ('two', 'CARDINAL'), ('Pune', 'GPE'), ('second', 'ORDINAL'), ('Manesar', 'LOC'), ('One', 'CARDINAL'), ('75%', 'PERCENT'), ('65%', 'PERCENT'), ('70% to 73%', 'PERCENT'), ('the current financial year', 'DATE'), ('Sanjay Thapar', 'PERSON'), ('Walter Pack', 'PERSON'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('Walter Pack Spain', 'PERSON'), ('Walter Pack India', 'PERSON'), ('IML', 'ORG'), ('IME', 'ORG'), ('this year', 'DATE'), ('India', 'GPE'), ('about 20% to 25%', 'PERCENT'), ('Walter Pack', 'PERSON'), ('This year', 'DATE'), ('Walter Pack', 'PERSON'), ('India', 'GPE'), ('Walter Pack', 'PERSON'), ('Devanshi Dhruva', 'PERSON'), ('WPI', 'ORG'), ('50%', 'PERCENT'), ('SJS', 'ORG'), ('Exotech', 'ORG'), ('Sanjay', 'ORG'), ('20% to 25%', 'PERCENT'), ('Ronak Mehta', 'PERSON'), ('JM Financial', 'ORG'), ('Ronak Mehta', 'PERSON'), ('WPI', 'ORG'), ('PV', 'FAC'), ('SJS', 'ORG'), ('WPI', 'PERSON'), ('K.A. Joseph', 'PERSON'), ('One', 'CARDINAL'), ('two', 'CARDINAL'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('about 30 to 40', 'CARDINAL'), ('this year', 'DATE'), ('12', 'CARDINAL'), ('13', 'CARDINAL')]
#
# --- Chunk_11 ---
# Summary: Sanjay Thapar: "Large in-mold forming parts are the forte of                 Walter Pack India" Mahendra: "Our strategy always has been that we take customers and we grow them into mega counts" "We are working on some development projects which I think are very exciting technologies"
# Growth_prospects: ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('almost about 50%', 'PERCENT'), ('SJS', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('Joe', 'PERSON'), ('Walter Pack India', 'PERSON'), ('Walter Pack', 'PERSON'), ('two', 'CARDINAL'), ('Bajaj', 'PERSON'), ('Royal Enfield', 'PERSON'), ('Honda', 'ORG'), ('IML', 'ORG'), ('EV', 'ORG'), ('IML', 'ORG'), ('IMD', 'ORG'), ('IME', 'ORG'), ('two', 'CARDINAL'), ('IML', 'ORG'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('Walter Pack', 'PERSON'), ('three', 'CARDINAL'), ('Devanshi Dhruva', 'PERSON'), ('Exotech', 'ORG'), ('Walter Pack', 'PERSON'), ('Exotech', 'PERSON'), ('Walter Pack', 'PERSON'), ('Mahindra', 'ORG'), ('Exotech', 'PERSON'), ('Maruti', 'PRODUCT'), ('Tata Motors', 'ORG'), ('Walter Pack', 'PERSON'), ('two', 'CARDINAL'), ('Ronak Mehta', 'PERSON'), ('Autoliv', 'ORG'), ('Toyota', 'ORG'), ('Tsusho', 'PERSON'), ('India', 'GPE'), ('Sanjay Thapar', 'PERSON'), ('Indian', 'NORP'), ('Autoliv', 'ORG'), ('India', 'GPE'), ('SJS', 'ORG'), ('Ronak Mehta', 'PERSON'), ('One', 'CARDINAL'), ('Mahendra', 'PERSON'), ('Mahendra', 'PERSON'), ('YoY', 'GPE'), ('QoQ', 'ORG'), ('Exotech', 'NORP')]
#
# --- Chunk_12 ---
# Summary: WPI revenue for this quarter grew 21% YoY to Rs 356 million. Exotech sales quarter-on-quarter was also slightly better than expected. In-Mold Electronics (IME) is still under development and will take 2-3 years to reach market.
# Growth_prospects:  ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects:     ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('two', 'CARDINAL'), ('One', 'CARDINAL'), ('one', 'CARDINAL'), ('GST', 'ORG'), ('8 million', 'CARDINAL'), ('two', 'CARDINAL'), ('quarter', 'DATE'), ('Karn Bhargava', 'PERSON'), ('WealthBridge Capital Advisors', 'ORG'), ('Karn Bhargava', 'PERSON'), ('two', 'CARDINAL'), ('WPI', 'PERSON'), ('the quarter', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('WPI', 'PERSON'), ('this quarter', 'DATE'), ('21%', 'PERCENT'), ('YoY', 'GPE'), ('356 million', 'CARDINAL'), ('Karn Bhargava', 'PERSON'), ('IME', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('two', 'CARDINAL'), ('four', 'CARDINAL'), ('ICE', 'ORG'), ('PCB', 'ORG'), ('2-3 years', 'DATE'), ('IME', 'ORG'), ('Walter Pack', 'PERSON'), ('Walter Pack Spain', 'PERSON'), ('Walter Pack Spain', 'PERSON'), ('IME', 'ORG'), ('IML', 'ORG'), ('IMF', 'ORG'), ('India', 'GPE'), ('Karn Bhargava', 'PERSON'), ('Walter Pack', 'PERSON'), ('Spain', 'GPE'), ('K.A. Joseph', 'PERSON'), ('Shrinjana Mittal', 'ORG'), ('RatnaTraya Capital', 'ORG'), ('Shrinjana Mittal', 'ORG'), ('two', 'CARDINAL'), ('One', 'CARDINAL'), ('Exotech', 'ORG'), ('quarter-on-quarter', 'DATE')]
#
# --- Chunk_13 ---
# Summary: Q2 and Q4 are usually stronger quarters for us due to festive season and seasonality. Asia, EMEA and South America have grown well. North America and Europe still continue to be in the recovery mode. We feel that we should come back to the pre-disruption levels that were there last year.
# Growth_prospects:  ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('Q2', 'CARDINAL'), ('Q4', 'PRODUCT'), ('QoQ', 'ORG'), ('Q4', 'PRODUCT'), ('Sanjay Thapar', 'PERSON'), ('Exotech', 'ORG'), ('this year', 'DATE'), ('John \nDeere', 'PERSON'), ('North America', 'LOC'), ('Geberit', 'GPE'), ('two', 'CARDINAL'), ('this quarter', 'DATE'), ('Exotech', 'PERSON'), ('Shrinjana Mittal', 'ORG'), ('Second', 'ORDINAL'), ('around 11%', 'PERCENT'), ('last quarter', 'DATE'), ('this quarter', 'DATE'), ('Mahendra Naredi', 'PERSON'), ('Last quarter', 'DATE'), ('7.9%', 'PERCENT'), ('11%', 'PERCENT'), ('Devanshi Dhruva', 'PERSON'), ('the entire last year', 'DATE'), ('Europe', 'LOC'), ('North America', 'LOC'), ('the year', 'DATE'), ('almost 32%', 'PERCENT'), ('this year', 'DATE'), ('Europe', 'LOC'), ('this quarter', 'DATE'), ('last year same quarter', 'DATE'), ('Shrinjana Mittal', 'ORG'), ('the year', 'DATE'), ('around 20%', 'PERCENT'), ('25%', 'PERCENT'), ('Sanjay Thapar', 'PERSON'), ('QoQ', 'ORG'), ('about 90%', 'PERCENT'), ('this last quarter', 'DATE'), ('the quarter a \nyear before', 'DATE'), ('Asia', 'LOC'), ('EMEA', 'ORG'), ('South America', 'LOC'), ('North America', 'LOC'), ('Europe', 'LOC'), ('last \nyear', 'DATE'), ('a year ago', 'DATE'), ('Ridhima Goyal', 'ORG'), ('Acquaintbee Ventures', 'ORG'), ('Ridhima Goyal', 'PRODUCT'), ('Sanjay', 'PERSON'), ('Devanshi', 'PERSON'), ('one', 'CARDINAL'), ('this quarter', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('second', 'ORDINAL'), ('Ridhima Goyal', 'PRODUCT'), ('this quarter', 'DATE')]
#
# --- Chunk_14 ---
# Summary: Consumer durables was a little muted growth; I would say almost about 2% - 3% and overall as a percent of sales, it was somewhere around 15% - 16% of our sales. The SJS product portfolio has very bright potential because we are underpenetrated in North America as I mentioned earlier.
# Growth_prospects: ...
# Business_changes:   ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('almost about 2% - 3%', 'PERCENT'), ('around 15% - 16%', 'PERCENT'), ('Ridhima Goyal', 'PRODUCT'), ('Devanshi Dhruva', 'PERSON'), ('Ridhima Goyal', 'PRODUCT'), ('two, three years', 'DATE'), ('five years', 'DATE'), ('Sanjay Thapar', 'PERSON'), ('Walter Pack', 'PERSON'), ('the Fascia Plate', 'LOC'), ('Walter Pack', 'PERSON'), ('Legrand', 'PERSON'), ('India', 'GPE'), ('SJS', 'ORG'), ('North America', 'LOC'), ('South \nAmerica', 'LOC'), ('North America', 'LOC'), ('Europe', 'LOC'), ('Legrand', 'CARDINAL'), ('IML', 'ORG'), ('Whirlpool', 'PERSON'), ('two', 'CARDINAL'), ('Two', 'CARDINAL'), ('four', 'CARDINAL'), ('Walter Pack', 'PERSON'), ('Walter Pack', 'PERSON'), ('about 20% - 25%', 'PERCENT'), ('Devanshi Dhruva', 'PERSON'), ('last year', 'DATE'), ('Mabe', 'PERSON'), ('IFB', 'ORG'), ('year', 'DATE'), ('two', 'CARDINAL'), ('Ridhima Goyal', 'PRODUCT'), ('Devanshi Dhruva', 'PERSON'), ('20%', 'PERCENT'), ('25%', 'PERCENT'), ('almost 90%', 'PERCENT'), ('SJS', 'ORG'), ('Exotech', 'ORG')]
#
# --- Chunk_15 ---
# Summary: Almost around 90% of the order book is                 confirmed for FY24, says Devanshi Dhruva. SJS has common customers with Tata Motors and Mahindra. The company is entering many new exciting areas like optical plastics, which it will do for the first time.
# Growth_prospects: ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('WPI', 'PERSON'), ('Devanshi Dhruva', 'PERSON'), ('WPI', 'PERSON'), ('WPI', 'PERSON'), ('almost around 90%', 'PERCENT'), ('Ridhima Goyal', 'PRODUCT'), ('WPI', 'ORG'), ('SJS', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('WPI', 'PERSON'), ('Tata Motors', 'ORG'), ('Tata \nMotors', 'ORG'), ('SJS', 'ORG'), ('Tata Motors', 'ORG'), ('Mahindra', 'ORG'), ('Mahindra', 'GPE'), ('Rohan Advant', 'ORG'), ('Rohan Advant', 'PERSON'), ('first', 'ORDINAL'), ('Walter Pack', 'PERSON'), ('Mahendra Naredi', 'PERSON'), ('Walter Pack', 'PERSON'), ('3.5%', 'PERCENT'), ('around 1%', 'PERCENT'), ('Rohan Advant', 'PERSON'), ('1%', 'PERCENT'), ('Mahendra Naredi', 'PERSON'), ('Rohan Advant', 'PERSON'), ('Secondly', 'ORDINAL'), ('50%', 'PERCENT'), ('40%', 'PERCENT'), ('Walter Pack', 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('40%', 'PERCENT'), ('PAT', 'ORG'), ('three', 'CARDINAL'), ('first', 'ORDINAL')]
#
# --- Chunk_16 ---
# Summary: Sanjay Thapar: SJS standalone we do close to about 30% 32% of the EBITDA. Walter Pack is not existent in many of the customers that SJS already has a strong relationship with. So cross selling, exports and penetrating the Indian market faster are the growth vectors for Walter Pack.
# Growth_prospects: ...
# Business_changes:   ...
# Key_triggers: ...
# Material_effects:   ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27, 2023 \n \n', 'DATE'), ('SJS', 'ORG'), ('about 30%', 'PERCENT'), ('32%', 'PERCENT'), ('five to six years', 'DATE'), ('40%', 'PERCENT'), ('Mahendra Naredi', 'PERSON'), ('Walter Pack', 'PERSON'), ('three', 'CARDINAL'), ('PAT', 'ORG'), ('40%', 'PERCENT'), ('last year', 'DATE'), ('Amit Hiranandani', 'ORG'), ('SMIFS Limited', 'ORG'), ('WPI', 'ORG'), ('almost zero', 'CARDINAL'), ('WPI', 'PERSON'), ('WPI', 'PERSON'), ('Spain', 'GPE'), ('WPI', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('WPI', 'ORG'), ('IML', 'ORG'), ('IMF', 'ORG'), ('Whirlpool', 'PERSON'), ('Samsung', 'ORG'), ('IML', 'ORG'), ('IME', 'ORG'), ('Walter Pack', 'PERSON'), ('Walter Pack', 'PERSON'), ('SJS', 'ORG'), ('Walter Pack', 'PERSON'), ('Indian', 'NORP'), ('IME', 'ORG'), ('Walter \nPack', 'PERSON'), ('Devanshi Dhruva', 'PERSON'), ('SJS', 'ORG'), ('Exotech', 'PERSON'), ('20% to 25%', 'PERCENT'), ('20% to 25%', 'PERCENT'), ('Walter Pack', 'PERSON')]
#
# --- Chunk_17 ---
# Summary: Amit Hiranandani: At optimum utilization capacity of WPI, how much revenue can SJS generate? Devanshi Dhruva: We are at a capacity utilization of 60% to 70% and we can generate revenue close to                 Rs.200 crores.
# Growth_prospects:  ...
# Business_changes: ...
# Key_triggers: ...
# Material_effects:   ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('the next three to five years', 'DATE'), ('WPI', 'ORG'), ('Devanshi Dhruva', 'PERSON'), ('60% to 70%', 'PERCENT'), ('Rs.200', 'NORP'), ('Rs.200', 'NORP'), ('Devanshi Dhruva', 'PERSON'), ('One', 'CARDINAL'), ('SJS', 'ORG'), ('secondly', 'ORDINAL'), ('annual', 'DATE'), ('SJS', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('one', 'CARDINAL'), ('Q2', 'CARDINAL'), ('WPI', 'PERSON'), ('WPI', 'ORG'), ('Vishal Khurana', 'PERSON'), ('Vishal Khurana', 'PERSON'), ('first', 'ORDINAL'), ('two', 'CARDINAL'), ('SJS', 'ORG'), ('Sanjay Thapar', 'PERSON'), ('Hero', 'ORG'), ('SJS', 'ORG'), ('Devanshi Dhruva', 'PERSON'), ('Classic Stripes', 'PRODUCT')]
#
# --- Chunk_18 ---
# Summary: Vishal Khurana: In the previous quarter investor presentation, we had mentioned that we had                 onboarded Foxconn, who will be making electric vehicles in India and we'll be supplying                 aesthetics to them. So may I know when they are going to put up that facility for this contract                 manufacturing of EVs that they'll do? Sanjay Thapar:                 Foxconn is not going to make EV, Foxconn is going to supply parts to EV.
# Growth_prospects:  ...
# Business_changes:  ...
# Key_triggers: ...
# Material_effects: ...
# Entities: [('SJS Enterprises', 'ORG'), ('July 27,', 'DATE'), ('2023', 'DATE'), ('Vishal Khurana', 'PERSON'), ('Second', 'ORDINAL'), ('the previous quarter', 'DATE'), ('Foxconn', 'GPE'), ('India', 'GPE'), ('Sanjay Thapar', 'PERSON'), ('Foxconn', 'GPE'), ('EV', 'GPE'), ('Foxconn', 'GPE'), ('EV', 'ORG'), ('last quarter', 'DATE'), ('Foxconn', 'GPE'), ('EV', 'ORG'), ('Q2', 'CARDINAL'), ('Vishal Khurana', 'PERSON'), ('Sanjay Thapar', 'PERSON'), ('IML', 'ORG'), ('Vishal Khurana', 'PERSON'), ('India', 'GPE'), ('Sanjay Thapar', 'PERSON'), ('this last \nquarter', 'DATE'), ('Devanshi Dhruva', 'PERSON'), ('JM Financial', 'ORG')]
